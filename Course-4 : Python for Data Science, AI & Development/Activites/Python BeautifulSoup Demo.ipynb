# %% [markdown]
# What are the 4 types of HTTP headers?
#
# The Content-Length and Content-Type standard HTTP entity headers can be specified in a request.
# The Content-Length, Content-Location, Content-Range, Content-Type, and Server standard HTTP entity headers can be returned in response to a request.

# %%
# !python -m install requests
# Out:
# /usr/bin/python3: No module named install

# %%
import requests
response = requests.get('https://randomuser.me/api/')
print(response.status_code)
print(response.reason) #response.reason
# Out:
# 200
# OK

# %%
import requests
response = requests.get('https://randomuser.me/api/s')
print(response.status_code)
print(response.reason) #response.reason
# Out:
# 404
# Not Found

# %%
import requests
response = requests.get('https://randomuser.me/api/')
response.text
# Out:
# '{"results":[{"gender":"male","name":{"title":"Mr","first":"Ido","last":"Meeuwis"},"location":{"street":{"number":6102,"name":"Ep Schuilinghstraat"},"city":"Ulrum","state":"Noord-Holland","country":"Netherlands","postcode":"2416 AI","coordinates":{"latitude":"34.5518","longitude":"-47.7666"},"timezone":{"offset":"+5:30","description":"Bombay, Calcutta, Madras, New Delhi"}},"email":"ido.meeuwis@example.com","login":{"uuid":"67b98dad-5f33-40fd-afed-fb63188cdc1b","username":"tinysnake998","password":"willard","salt":"w9ooa73k","md5":"5d560bceb32a625915926e83ba395d4c","sha1":"90653129e0d4082961fa764e3f5ecff5db9cd547","sha256":"b2382db70f14308fa2893bf379e2a7e0cb584b31572994164816af8b1df50d88"},"dob":{"date":"1984-10-06T11:38:15.009Z","age":38},"registered":{"date":"2010-08-08T10:26:44.956Z","age":12},"phone":"(0815) 737712","cell":"(06) 88307821","id":{"name":"BSN","value":"43492542"},"picture":{"large":"https://randomuser.me/api/portraits/men/19.jpg","medium":"https://randomuser.me/api/p
# ...

# %%
import requests
response = requests.get('https://api.thedogapi.com/v1/breeds/1')
response.headers.get('content-Type')
response.json()
response.json()['name']
# Out:
# 'Affenpinscher'

# %%
requests.post('https://api.thedogapi.com/v1/breeds/1')
# Out:
# <Response [405]>

# %%
requests.delete('https://api.thedogapi.com/v1/breeds/1')
# Out:
# <Response [405]>
