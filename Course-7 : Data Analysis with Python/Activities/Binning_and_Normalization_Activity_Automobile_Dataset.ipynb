# %%
import pandas as pd

url = 'https://github.com/lk-learner/IBM-data-analyst-professional-certificate/raw/main/Course-7%20:%20Data%20Analysis%20with%20Python/Activities/auto-mpg%20.xlsx'
df = pd.read_excel(url)
df
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18          8         307.0         130    3504          12.0
# 1    15          8         350.0         165    3693          11.5
# 2    18          8         318.0         150    3436          11.0
# 3    16          8         304.0         150    3433          12.0
# 4    17          8         302.0         140    3449          10.5
# ..  ...        ...           ...         ...     ...           ...
# 93   14          8         318.0         150    4237          14.5
# 94   13          8         440.0         215    4735          11.0
# 95   12          8         455.0         225    4951          11.0
# 96   13          8         360.0         175    3821          11.0
# 97   18          6         225.0         105    3121          16.5
#
#     model year  origin                      car name CAR Number
# 0         70.0       1     chevrolet chevelle malibu    L6V 043
# ...

# %% [markdown]
# #### 1. Drop column Origin from the dataset.

# %%
#Drop column Origin from the dataset.
df = df.drop('origin', axis=1)
df
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18          8         307.0         130    3504          12.0
# 1    15          8         350.0         165    3693          11.5
# 2    18          8         318.0         150    3436          11.0
# 3    16          8         304.0         150    3433          12.0
# 4    17          8         302.0         140    3449          10.5
# ..  ...        ...           ...         ...     ...           ...
# 93   14          8         318.0         150    4237          14.5
# 94   13          8         440.0         215    4735          11.0
# 95   12          8         455.0         225    4951          11.0
# 96   13          8         360.0         175    3821          11.0
# 97   18          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# 0         70.0     chevrolet chevelle malibu    L6V 043
# ...

# %% [markdown]
# #### 2. Find out all the missing values in the dataset and replace it with its most appropriate replacement.

# %%
#Find out all the missing values in the dataset and replace it with its most appropriate replacement. 
# Find all the missing values
print(df.isna().sum())
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    2
# model year      2
# car name        0
# CAR Number      7
# dtype: int64

# %%
# Replace missing values in 'acceleration' column with its median
df['acceleration'] = df['acceleration'].fillna(df['acceleration'].median())

# %%
# Replace missing values in 'model year' column with its median
df['model year'] = df['model year'].fillna(df['model year'].median())

# %%
# Replace missing values in 'CAR Number' column with LAKSHMI
df['CAR Number'] = df['CAR Number'].fillna('LAKSHMI')

# %%
print(df.isna().sum())
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# car name        0
# CAR Number      0
# dtype: int64

# %% [markdown]
# #### 3. Find and remove duplicate entries for the column ‘ CAR Number’

# %%
#Find number of duplicates in CAR Number column
df['CAR Number'].duplicated().sum()
# Out:
# 8

# %%
# Extract duplicate rows
df.loc[df.duplicated('CAR Number'), :]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 17   15          8         383.0         170    3563          10.0
# 26   10          8         307.0         200    4376          15.0
# 29   27          4          97.0          88    2130          14.5
# 32   25          4          98.0          80    2046          19.0
# 34   16          6         225.0         105    3439          15.5
# 52   30          4          88.0          76    2065          14.5
# 54   35          4          72.0          69    1613          18.0
# 73   13          8         307.0         130    4098          14.0
#
#     model year                          car name CAR Number
# 17        70.0               dodge challenger se     TN5678
# 26        70.0                         chevy c20    LAKSHMI
# 29        71.0                      datsun pl510    LAKSHMI
# 32        71.0                        ford pinto    LAKSHMI
# 34        71.0         plymouth satellite custom     JHGY59
# ...

# %%
df.drop_duplicates('CAR Number', inplace=True)

# %%
df
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18          8         307.0         130    3504          12.0
# 1    15          8         350.0         165    3693          11.5
# 2    18          8         318.0         150    3436          11.0
# 3    16          8         304.0         150    3433          12.0
# 4    17          8         302.0         140    3449          10.5
# ..  ...        ...           ...         ...     ...           ...
# 93   14          8         318.0         150    4237          14.5
# 94   13          8         440.0         215    4735          11.0
# 95   12          8         455.0         225    4951          11.0
# 96   13          8         360.0         175    3821          11.0
# 97   18          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# 0         70.0     chevrolet chevelle malibu    L6V 043
# ...

# %% [markdown]
# #### 4. Get the basic insights:
# Display the first five and last five rows
#
# Display all the column names in the dataset
#
# Display the concise summary of your dataset
#
# Display the name of the car with maximum number of horsepower.

# %%
#Display the first five and last five rows
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130    3504          12.0        70.0
# 1   15          8         350.0         165    3693          11.5        70.0
# 2   18          8         318.0         150    3436          11.0        70.0
# 3   16          8         304.0         150    3433          12.0        70.0
# 4   17          8         302.0         140    3449          10.5        70.0
#
#                     car name CAR Number
# 0  chevrolet chevelle malibu    L6V 043
# 1          buick skylark 320     RTY079
# 2         plymouth satellite     MTP600
# 3              amc rebel sst     MNJ000
# 4                ford torino   JEETMEET

# %%
#Display the first five and last five rows
df.tail()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 93   14          8         318.0         150    4237          14.5
# 94   13          8         440.0         215    4735          11.0
# 95   12          8         455.0         225    4951          11.0
# 96   13          8         360.0         175    3821          11.0
# 97   18          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# 93        73.0      plymouth fury gran sedan     FGTEE4
# 94        73.0  chrysler new yorker brougham     GTTYR6
# 95        73.0      buick electra 225 custom    TTGGT53
# 96        73.0       amc ambassador brougham    TGTYY67
# 97        73.0              plymouth valiant     HUYT76

# %%
#Display all the column names in the dataset
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'car name', 'CAR Number'],
#       dtype='object')

# %%
#Display the concise summary of your dataset
df.describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  90.000000  90.000000     90.000000   90.000000    90.000000
# mean   18.133333   6.366667    259.516667  132.466667  3380.088889
# std     5.502196   1.863005    124.299937   47.763274   961.671714
# min     9.000000   3.000000     70.000000   46.000000  1773.000000
# 25%    14.000000   4.000000    121.000000   90.000000  2398.250000
# 50%    17.000000   8.000000    303.000000  140.000000  3442.500000
# 75%    22.750000   8.000000    351.000000  165.000000  4264.750000
# max    31.000000   8.000000    455.000000  225.000000  5140.000000
#
#        acceleration  model year
# count     90.000000   90.000000
# mean      13.955556   71.288889
# std        3.011816    1.051959
# min        8.000000   70.000000
# 25%       12.000000   70.000000
# 50%       13.500000   71.000000
# 75%       15.500000   72.000000
# max       23.500000   73.000000

# %%
#Display the name of the car with maximum number of horsepower
print(df['horsepower'].max())
# Out:
# 225

# %% [markdown]
# #### 5. In our dataset, the fuel consumption column is "mpg" and is represented by mpg (miles per gallon) unit. Assume we are developing an application in a country that accepts fuel consumption with the L/100km standard. change the name of the column to "L/100km".

# %%
df.rename(columns={'mpg':'L/100km'}, inplace=True)
df
# Out:
#     L/100km  cylinders  displacement  horsepower  weight  acceleration  \
# 0        18          8         307.0         130    3504          12.0
# 1        15          8         350.0         165    3693          11.5
# 2        18          8         318.0         150    3436          11.0
# 3        16          8         304.0         150    3433          12.0
# 4        17          8         302.0         140    3449          10.5
# ..      ...        ...           ...         ...     ...           ...
# 93       14          8         318.0         150    4237          14.5
# 94       13          8         440.0         215    4735          11.0
# 95       12          8         455.0         225    4951          11.0
# 96       13          8         360.0         175    3821          11.0
# 97       18          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# 0         70.0     chevrolet chevelle malibu    L6V 043
# ...

# %% [markdown]
# #### 6. Normalize the column “Weight” so that the values range from 0 to 1

# %%
# normalize the values in column “Weight” to a range of 0-1
df['weight'] = (df['weight'] - df['weight'].min()) / (df['weight'].max() - df['weight'].min())

df
# Out:
#     L/100km  cylinders  displacement  horsepower    weight  acceleration  \
# 0        18          8         307.0         130  0.514108          12.0
# 1        15          8         350.0         165  0.570241          11.5
# 2        18          8         318.0         150  0.493911          11.0
# 3        16          8         304.0         150  0.493020          12.0
# 4        17          8         302.0         140  0.497772          10.5
# ..      ...        ...           ...         ...       ...           ...
# 93       14          8         318.0         150  0.731809          14.5
# 94       13          8         440.0         215  0.879715          11.0
# 95       12          8         455.0         225  0.943867          11.0
# 96       13          8         360.0         175  0.608257          11.0
# 97       18          6         225.0         105  0.400356          16.5
#
#     model year                      car name CAR Number
# ...

# %% [markdown]
# #### 7. Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include scaling the variable so the variable average is 0, scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1

# %% [markdown]
# #### 8. Approach: replace original value by (original value)/(maximum value)

# %%
# normalize the values in column “Weight” to a range of 0-1
df['weight'] = df['weight']/df['weight'].max() 
df
# Out:
#     L/100km  cylinders  displacement  horsepower    weight  acceleration  \
# 0        18          8         307.0         130  0.514108          12.0
# 1        15          8         350.0         165  0.570241          11.5
# 2        18          8         318.0         150  0.493911          11.0
# 3        16          8         304.0         150  0.493020          12.0
# 4        17          8         302.0         140  0.497772          10.5
# ..      ...        ...           ...         ...       ...           ...
# 93       14          8         318.0         150  0.731809          14.5
# 94       13          8         440.0         215  0.879715          11.0
# 95       12          8         455.0         225  0.943867          11.0
# 96       13          8         360.0         175  0.608257          11.0
# 97       18          6         225.0         105  0.400356          16.5
#
#     model year                      car name CAR Number
# ...

# %% [markdown]
# #### 9. In our dataset, "horsepower" is a real valued variable ranging from 48 to 288, it has 57 unique values. What if we only care about the price difference between cars with high horsepower, medium horsepower, and little horsepower (3 types)? Can we rearrange them into three ‘bins' to simplify analysis?

# %%
df.dtypes
# Out:
# L/100km           int64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight          float64
# acceleration    float64
# model year      float64
# car name         object
# CAR Number       object
# dtype: object

# %%
# Categories  binning
import numpy as np
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 46.        , 105.66666667, 165.33333333, 225.        ])

# %% [markdown]
# #### 10. We will use the Pandas method 'cut' to segment the 'horsepower' column into 3 bins

# %%
#We apply the function "cut" the determine what each value of "df['horsepower']" belongs to.
import pandas as pd
group_names = ['Low', 'Medium', 'High']
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head()
# Out:
#    horsepower horsepower-binned
# 0         130            Medium
# 1         165            Medium
# 2         150            Medium
# 3         150            Medium
# 4         140            Medium

# %% [markdown]
# #### 11. Use a histogram to visualize the distribution of bins we created above.

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower-binned"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower-binned")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# #### 12. Detect outliers using Z-score and remove them

# %%
df
# Out:
#     L/100km  cylinders  displacement  horsepower    weight  acceleration  \
# 0        18          8         307.0         130  0.514108          12.0
# 1        15          8         350.0         165  0.570241          11.5
# 2        18          8         318.0         150  0.493911          11.0
# 3        16          8         304.0         150  0.493020          12.0
# 4        17          8         302.0         140  0.497772          10.5
# ..      ...        ...           ...         ...       ...           ...
# 93       14          8         318.0         150  0.731809          14.5
# 94       13          8         440.0         215  0.879715          11.0
# 95       12          8         455.0         225  0.943867          11.0
# 96       13          8         360.0         175  0.608257          11.0
# 97       18          6         225.0         105  0.400356          16.5
#
#     model year                      car name CAR Number horsepower-binned
# ...

# %%
df = df.drop(['car name', 'CAR Number', 'horsepower-binned'], axis=1)

# %%
df
# Out:
#     L/100km  cylinders  displacement  horsepower    weight  acceleration  \
# 0        18          8         307.0         130  0.514108          12.0
# 1        15          8         350.0         165  0.570241          11.5
# 2        18          8         318.0         150  0.493911          11.0
# 3        16          8         304.0         150  0.493020          12.0
# 4        17          8         302.0         140  0.497772          10.5
# ..      ...        ...           ...         ...       ...           ...
# 93       14          8         318.0         150  0.731809          14.5
# 94       13          8         440.0         215  0.879715          11.0
# 95       12          8         455.0         225  0.943867          11.0
# 96       13          8         360.0         175  0.608257          11.0
# 97       18          6         225.0         105  0.400356          16.5
#
#     model year
# 0         70.0
# 1         70.0
# 2         70.0
# 3         70.0
# ...

# %%
from scipy.stats import zscore

# Calculate the Z-score for each data point
z_scores = zscore(df)

# Identify the outliers
outliers = df[(z_scores > 3).any(axis=1)]

# Remove the outliers from the dataset
df = df[(z_scores < 3).all(axis=1)]

# %%
df
# Out:
#     L/100km  cylinders  displacement  horsepower    weight  acceleration  \
# 0        18          8         307.0         130  0.514108          12.0
# 1        15          8         350.0         165  0.570241          11.5
# 2        18          8         318.0         150  0.493911          11.0
# 3        16          8         304.0         150  0.493020          12.0
# 4        17          8         302.0         140  0.497772          10.5
# ..      ...        ...           ...         ...       ...           ...
# 93       14          8         318.0         150  0.731809          14.5
# 94       13          8         440.0         215  0.879715          11.0
# 95       12          8         455.0         225  0.943867          11.0
# 96       13          8         360.0         175  0.608257          11.0
# 97       18          6         225.0         105  0.400356          16.5
#
#     model year
# 0         70.0
# 1         70.0
# 2         70.0
# 3         70.0
# ...

# %%
df['zscore']=zscore(df["acceleration"])

df.loc[df['zscore'].abs()>3]
# Out:
# <ipython-input-29-4b6a13b42942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['zscore']=zscore(df["acceleration"])
# Empty DataFrame
# Columns: [L/100km, cylinders, displacement, horsepower, weight, acceleration, model year, zscore]
# Index: []
