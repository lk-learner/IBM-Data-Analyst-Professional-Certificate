# %% [markdown]
# #### Importing data

# %% [markdown]
# Creating API: Go to kaggle ---> my profile ---> Edit profile ---> Create new API token.
# It will prompt a download option, download the json on to your computer and upload it here.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c03acc26-0391-4b9a-a57e-92d2c743f10d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c03acc26-0391-4b9a-a57e-92d2c743f10d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d shivam2503/diamonds
# Out:
# diamonds.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# Make new directory:data

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %% [markdown]
# The following command will list files and sub-directories in the current directory

# %%
# !ls
# Out:
# data  diamonds.zip  kaggle.json  sample_data

# %% [markdown]
# Unzipping files in the sub-directories in the current directory

# %%
# !unzip  diamonds.zip -d data
# Out:
# Archive:  diamonds.zip
#   inflating: data/diamonds.csv

# %%
import pandas as pd
df = pd.read_csv('/content/data/diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...
