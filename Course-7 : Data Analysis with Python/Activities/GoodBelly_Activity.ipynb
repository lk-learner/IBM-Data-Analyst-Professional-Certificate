# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df = pd.read_excel('/content/GoodBelly-DataSet.xlsx', sheet_name='Real Data')
df
# Out:
#            Date Region                    Store  Units Sold  \
# 0    2010-05-04     FL  Biscayne (aka Aventura)  150.702088
# 1    2010-05-11     FL  Biscayne (aka Aventura)  197.403797
# 2    2010-05-18     FL  Biscayne (aka Aventura)  235.106172
# 3    2010-05-25     FL  Biscayne (aka Aventura)  226.692427
# 4    2010-06-01     FL  Biscayne (aka Aventura)  257.688151
# ...         ...    ...                      ...         ...
# 1381 2010-06-15     SW                 Veterans  192.685157
# 1382 2010-06-22     SW                 Veterans  173.720882
# 1383 2010-06-29     SW                 Veterans  278.582872
# 1384 2010-07-06     SW                 Veterans  122.229768
# 1385 2010-07-13     SW                 Veterans  166.893026
#
#       Average Retail Price  Sales Rep  Endcap  Demo  Demo1-3  Demo4-5  \
# 0                 4.390000          0       0     0        0        0
# 1                 3.997692          0       0     0        0        0
# ...

# %% [markdown]
# #### 1. Find how many records this data frame has;

# %%
# Number of records in the DataFrame
num_records = len(df)
print("Number of records:", num_records)
# Out:
# Number of records: 1386

# %% [markdown]
# #### 2. How many elements are there?

# %%
# Get the number of elements in the DataFrame
num_elements = df.size
print("Number of elements:", num_elements)
# Out:
# Number of elements: 16632

# %% [markdown]
# #### 3. What are the column names?

# %%
# Get the column names of the DataFrame
column_names = df.columns
print("Column names:", column_names)
# Out:
# Column names: Index(['Date', 'Region', 'Store', 'Units Sold', 'Average Retail Price',
#        'Sales Rep', 'Endcap', 'Demo', 'Demo1-3', 'Demo4-5', 'Natural',
#        'Fitness'],
#       dtype='object')

# %% [markdown]
# #### 4. What types of columns do we have in this data frame?

# %%
# Get the data types of each column
column_types = df.dtypes
column_types
# Out:
# Date                    datetime64[ns]
# Region                          object
# Store                           object
# Units Sold                     float64
# Average Retail Price           float64
# Sales Rep                        int64
# Endcap                           int64
# Demo                             int64
# Demo1-3                          int64
# Demo4-5                          int64
# Natural                          int64
# Fitness                          int64
# dtype: object

# %% [markdown]
# #### 5. Give the summary for the numeric columns in the dataset

# %%
# Get the summary of the numeric columns
numeric_summary = df.describe()
numeric_summary
# Out:
#         Units Sold  Average Retail Price    Sales Rep       Endcap  \
# count  1386.000000           1386.000000  1386.000000  1386.000000
# mean    253.820718              4.107093     0.549784     0.038240
# std     110.998731              0.463828     0.497695     0.191843
# min      47.559852              2.889286     0.000000     0.000000
# 25%     189.995471              3.775714     0.000000     0.000000
# 50%     236.735266              4.096667     1.000000     0.000000
# 75%     295.804391              4.425067     1.000000     0.000000
# max    1041.200256              6.251538     1.000000     1.000000
#
#               Demo      Demo1-3      Demo4-5      Natural      Fitness
# count  1386.000000  1386.000000  1386.000000  1386.000000  1386.000000
# mean      0.058442     0.156566     0.075758     1.448773     2.476190
# std       0.234661     0.363522     0.264705     0.975092     1.592789
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# #### 6. Calculate standard deviation for all numeric columns;

# %%
# Calculate the standard deviation for all numeric columns
std_dev = df.std()
print("Standard deviation for all numeric columns:\n", std_dev)
# Out:
# Standard deviation for all numeric columns:
#  Date                    22 days 03:27:15.853934319
# Units Sold                              110.998731
# Average Retail Price                      0.463828
# Sales Rep                                 0.497695
# Endcap                                    0.191843
# Demo                                      0.234661
# Demo1-3                                   0.363522
# Demo4-5                                   0.264705
# Natural                                   0.975092
# Fitness                                   1.592789
# dtype: object
# <ipython-input-23-199d0a0edb0c>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std_dev = df.std()

# %% [markdown]
# #### 7. What are the mean values of the first 50 records in the dataset?   Hint: use head() method to subset the first 50 records and then calculate the mean

# %%
# Subset the first 50 records and calculate the mean
mean_first_50 = df.head(50).mean()
print("Mean values of the first 50 records:\n", mean_first_50)
# Out:
# Mean values of the first 50 records:
#  Units Sold              186.280727
# Average Retail Price      4.128036
# Sales Rep                 0.000000
# Endcap                    0.100000
# Demo                      0.000000
# Demo1-3                   0.000000
# Demo4-5                   0.040000
# Natural                   1.300000
# Fitness                   1.560000
# dtype: float64
# <ipython-input-24-db6716d6c4f6>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_first_50 = df.head(50).mean()
# <ipython-input-24-db6716d6c4f6>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_first_50 = df.head(50).mean()
